# %%
# !jupyter --version
# Out:
# jupyter core     : 4.7.1
# jupyter-notebook : 6.3.0
# qtconsole        : 5.0.3
# ipython          : 7.22.0
# ipykernel        : 5.3.4
# jupyter client   : 6.1.12
# jupyter lab      : 3.0.14
# nbconvert        : 6.0.7
# ipywidgets       : 7.6.3
# nbformat         : 5.1.3
# traitlets        : 5.0.5

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.20.1'

# %%
pd.read_csv('C:\\Users\\USER\\Desktop\\OLUWATOMMY\\work\\data.csv')
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df=pd.read_csv('C:\\Users\\USER\\Desktop\\OLUWATOMMY\\work\\data.csv')

# %%
len(df)
# Out:
# 11914

# %%
n = 3
df.Make.value_counts()[:n]
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %%
n = 3
df.Make.value_counts()[:n].index.tolist()
# Out:
# ['Chevrolet', 'Ford', 'Volkswagen']

# %%
df.Model.nunique()
# Out:
# 915

# %%
df['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
df.groupby('Make').Model.nunique()
# Out:
# Make
# Acura            18
# Alfa Romeo        1
# Aston Martin     12
# Audi             34
# BMW              39
# Bentley          18
# Bugatti           1
# Buick            20
# Cadillac         30
# Chevrolet        63
# Chrysler         19
# Dodge            33
# FIAT              5
# Ferrari          14
# Ford             51
# GMC              30
# Genesis           1
# HUMMER            2
# Honda            21
# Hyundai          22
# Infiniti         38
# Kia              16
# Lamborghini       6
# Land Rover       11
# Lexus            46
# Lincoln          16
# Lotus             5
# Maserati          8
# Maybach           3
# Mazda            31
# McLaren           4
# Mercedes-Benz    40
# Mitsubishi       22
# Nissan           32
# Oldsmobile       18
# Plymouth         10
# Pontiac          20
# Porsche          12
# Rolls-Royce      10
# Saab              8
# Scion             8
# Spyker            1
# Subaru           16
# Suzuki           16
# Tesla             1
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
df['Engine Cylinders'].value_counts()
# Out:
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: Engine Cylinders, dtype: int64

# %%
df['Engine Cylinders'].fillna(value=6.0, inplace=True)

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
df.loc[df['Make'] == 'Lotus']
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
df[df.Make == "Lotus"]
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
df.loc[:, ["Engine HP","Engine Cylinders"]]
# Out:
#        Engine HP  Engine Cylinders
# 0          335.0               6.0
# 1          300.0               6.0
# 2          300.0               6.0
# 3          230.0               6.0
# 4          230.0               6.0
# ...          ...               ...
# 11909      300.0               6.0
# 11910      300.0               6.0
# 11911      300.0               6.0
# 11912      300.0               6.0
# 11913      221.0               6.0
#
# [11914 rows x 2 columns]

# %%
df[df.Make == "Lotus"][["Engine HP", "Engine Cylinders"]]
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
df[df.Make == "Lotus"][["Engine HP", "Engine Cylinders"]].drop_duplicates()
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
df_Lo = df[df.Make == "Lotus"][["Engine HP", "Engine Cylinders"]].drop_duplicates()

# %%
X = df_Lo.values
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
X1 = X.T
X1
# Out:
# array([[189., 218., 217., 350., 400., 276., 345., 257., 240.],
#        [  4.,   4.,   4.,   8.,   6.,   6.,   6.,   4.,   4.]])

# %%
X.T.dot(X)
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
XTX = X.T.dot(X)

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %%
XTV_inv = np.linalg.inv(XTX)
XTV_inv.sum()
# Out:
# 0.15475735843457794

# %%
XTV_inv.dot(X1).dot(y)
# Out:
# array([  4.59494481, -63.56432501])

# %%
w = XTV_inv.dot(X1).dot(y)
w
# Out:
# array([  4.59494481, -63.56432501])
